# %%
import pandas as pd
df = pd.read_csv('datasets/default_credit_card.csv', sep=";", header=0)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
X = df.drop(['default payment next month', 'SEX', 'EDUCATION', 'MARRIAGE'], axis=1)
y = df['default payment next month']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
pd.DataFrame(X_train).describe()
# Out:
#                  0             1             2             3             4   \
# count  2.250000e+04  2.250000e+04  2.250000e+04  2.250000e+04  2.250000e+04
# mean  -1.124237e-16 -9.789700e-17  2.463215e-17  1.768462e-17  2.084259e-17
# std    1.000022e+00  1.000022e+00  1.000022e+00  1.000022e+00  1.000022e+00
# min   -1.213873e+00 -1.575396e+00 -1.756924e+00 -1.555608e+00 -1.530474e+00
# 25%   -9.048112e-01 -8.149811e-01 -8.727838e-01 -7.238113e-01 -6.971243e-01
# 50%   -2.094217e-01 -1.631971e-01  1.135629e-02  1.079857e-01  1.362248e-01
# 75%    5.632333e-01  5.972177e-01  1.135629e-02  1.079857e-01  1.362248e-01
# max    6.435411e+00  4.725183e+00  7.084477e+00  5.930565e+00  6.803018e+00
#
#                  5             6             7             8             9   \
# count  2.250000e+04  2.250000e+04  2.250000e+04  2.250000e+04  2.250000e+04
# mean  -3.821141e-17 -4.800111e-17  3.221127e-17 -2.147418e-17 -3.868510e-17
# ...

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(11,))
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(11,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8162666666666667

# %%
scores = []
neurons = []

for i in range(1, 22):
    mlp = MLPClassifier(hidden_layer_sizes=(i))
    mlp.fit(X_train, y_train)
    score = mlp.score(X_test, y_test)
    scores.append(score)
    neurons.append(i)

import matplotlib.pyplot as plt
plt.plot(neurons, scores)
plt.show()

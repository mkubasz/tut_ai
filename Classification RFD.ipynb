# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Social_Network_Ads.csv")

# %%
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
X = dataset.iloc[:, 2: 3].values
y = dataset.iloc[:, 4].values

# %%
# podzial na dane
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
# trenowanie modelu
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200, criterion = 'gini', random_state = 10)
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac64be709115> in <module>
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 classifier = RandomForestClassifier(n_estimators = 200, criterion = 'gini', random_state = 10)
# ----> 4 classifier.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
# ocena poprawności działania
test_score = classifier.score(X_test, y_test)
test_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a3257b972d0e> in <module>
#       1 # ocena poprawności działania
# ----> 2 test_score = classifier.score(X_test, y_test)
#       3 test_score
#
# NameError: name 'X_test' is not defined

# %%
# porówanie wyników testowych
y_pred = classifier.predict(X_test)
plt.plot(y_test)
plt.plot(y_pred, color="red")
